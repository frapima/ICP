# %% [markdown]
# ## Ejemplo de Flume
#
# En este ejemplo vamos a configurar Flume para que vigile un directorio local en busca de nuevos ficheros de texto. Conforme se añadan ficheros, se envían sus líneas a la consola.

# %%
! mkdir -p flume
import os
os.chdir("flume")
! pwd
# Out:
# /media/notebooks/flume

# %%
# %%writefile /opt/examples/flume/conf/flume-ex1.conf
# # En primer lugar definimos los componentes princpales
# # (source, channel, sink).
# # agent1 es el nombre de mi agente, lo tendre que utilizar
# # en la orden para ejecutarlo (en algunas celdas mas abajo)
# agent1.sources = source1
# agent1.sinks = sink1
# agent1.channels = channel1
#
# # Enlazo mis componentes source - channel- sink
# agent1.sources.source1.channels = channel1
# agent1.sinks.sink1.channel = channel1
#
# # Configuro cada componente. Primero el source, de tipo spooldir,
# # le tenemos que indicar el directorio que vamos a utilizar
# agent1.sources.source1.type = spooldir
# agent1.sources.source1.spoolDir = /tmp/spooldir
#
# # Ahora configuramos el sink, de tipo logger.
# agent1.sinks.sink1.type = logger
#
# # Ahora el channel, de tipo file
# agent1.channels.channel1.type = file
# Out:
# Writing /opt/examples/flume/conf/flume-ex1.conf

# %%
! mkdir /tmp/spooldir

# %%
# ejecuto el agente. 
# --conf-file /opt/examples/flume/conf/flume-ex1.conf apunta al 
# archivo que hemos escrito unas celdas arriba. 
# --conf /opt/examples/flume/conf apunta al fichero de configuracion 
# de las opciones generales de flume.

! flume-ng agent \
    --conf /opt/examples/flume/conf \
    --conf-file /opt/examples/flume/conf/flume-ex1.conf \
    --name agent1
# Out:
# Info: Sourcing environment configuration script /opt/examples/flume/conf/flume-env.sh
# Info: Including Hadoop libraries found via (/usr/bin/hadoop) for HDFS access
# Info: Excluding /usr/lib/hadoop/lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-log4j12.jar from classpath
# Info: Including HBASE libraries found via (/usr/bin/hbase) for HBASE access
# Info: Excluding /usr/lib/hbase/bin/../lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/hbase/bin/../lib/slf4j-log4j12.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-log4j12.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-log4j12.jar from classpath
# Info: Excluding /usr/lib/zookeeper/lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/zookeeper/lib/slf4j-log4j12-1.7.5.jar from classpath
# Info: Excluding /usr/lib/zookeeper/lib/slf4j-log4j12.jar from classpath
# Info: Including Hive libraries found via () for Hive access
# + exec /usr/java/jdk1.7.0_67-cloudera/bin/java -Xmx4096m -XX:MaxPermSize=256M -cp '/opt/examples/flume/conf:/usr/lib/flume-ng/lib/*:/etc/hadoop/conf:/usr/lib/hadoop/lib/activation-1.1.jar:/usr/lib/hadoop/lib/apacheds-i18n-2.0.0-M15.jar:/usr/lib/hadoop/lib/apacheds-kerberos-codec-2.0.0-M15.jar:/usr/lib/hadoop/lib/api-asn1-api-1.0.0-M20.jar:/usr/lib/hadoop/lib/api-util-1.0.0-M20.jar:/usr/lib/hadoop/lib/asm-3.2.jar:/usr/lib/hadoop/lib/avro.jar:/usr/lib/hadoop/lib/aws-java-sdk-core-1.10.6.jar:/usr/lib/hadoop/lib/aws-java-sdk-kms-1.10.6.jar:/usr/lib/hadoop/lib/aws-java-sdk-s3-1.10.6.jar:/usr/lib/hadoop/lib/commons-beanutils-1.7.0.jar:/usr/lib/hadoop/lib/commons-beanutils-core-1.8.0.jar:/usr/lib/hadoop/lib/commons-cli-1.2.jar:/usr/lib/hadoop/lib/commons-codec-1.4.jar:/usr/lib/hadoop/lib/commons-collections-3.2.2.jar:/usr/lib/hadoop/lib/commons-compress-1.4.1.jar:/usr/lib/hadoop/lib/commons-configuration-1.6.jar:/usr/lib/hadoop/lib/commons-digester-1.8.jar:/usr/lib/hadoop/lib/commons-el-1.0.jar:/usr/lib/hadoop/lib/commons-httpclient-3.1.jar:/usr/lib/hadoop/lib/commons-io-2.4.jar:/usr/lib/hadoop/lib/commons-lang-2.6.jar:/usr/lib/hadoop/lib/commons-logging-1.1.3.jar:/usr/lib/hadoop/lib/commons-math3-3.1.1.jar:/usr/lib/hadoop/lib/commons-net-3.1.jar:/usr/lib/hadoop/lib/curator-client-2.7.1.jar:/usr/lib/hadoop/lib/curator-framework-2.7.1.jar:/usr/lib/hadoop/lib/curator-recipes-2.7.1.jar:/usr/lib/hadoop/lib/gson-2.2.4.jar:/usr/lib/hadoop/lib/guava-11.0.2.jar:/usr/lib/hadoop/lib/hamcrest-core-1.3.jar:/usr/lib/hadoop/lib/htrace-core4-4.0.1-incubating.jar:/usr/lib/hadoop/lib/httpclient-4.2.5.jar:/usr/lib/hadoop/lib/httpcore-4.2.5.jar:/usr/lib/hadoop/lib/hue-plugins-3.9.0-cdh5.7.0.jar:/usr/lib/hadoop/lib/jackson-core-asl-1.8.8.jar:/usr/lib/hadoop/lib/jackson-jaxrs-1.8.8.jar:/usr/lib/hadoop/lib/jackson-mapper-asl-1.8.8.jar:/usr/lib/hadoop/lib/jackson-xc-1.8.8.jar:/usr/lib/hadoop/lib/jasper-compiler-5.5.23.jar:/usr/lib/hadoop/lib/jasper-runtime-5.5.23.jar:/usr/lib/hadoop/lib/java-xmlbuilder-0.4.jar:/usr/lib/hadoop/lib/jaxb-api-2.2.2.jar:/usr/lib/hadoop/lib/jaxb-impl-2.2.3-1.jar:/usr/lib/hadoop/lib/jersey-core-1.9.jar:/usr/lib/hadoop/lib/jersey-json-1.9.jar:/usr/lib/hadoop/lib/jersey-server-1.9.jar:/usr/lib/hadoop/lib/jets3t-0.9.0.jar:/usr/lib/hadoop/lib/jettison-1.1.jar:/usr/lib/hadoop/lib/jetty-6.1.26.cloudera.4.jar:/usr/lib/hadoop/lib/jetty-util-6.1.26.cloudera.4.jar:/usr/lib/hadoop/lib/jsch-0.1.42.jar:/usr/lib/hadoop/lib/jsp-api-2.1.jar:/usr/lib/hadoop/lib/jsr305-3.0.0.jar:/usr/lib/hadoop/lib/junit-4.11.jar:/usr/lib/hadoop/lib/log4j-1.2.17.jar:/usr/lib/hadoop/lib/logredactor-1.0.3.jar:/usr/lib/hadoop/lib/mockito-all-1.8.5.jar:/usr/lib/hadoop/lib/native:/usr/lib/hadoop/lib/netty-3.6.2.Final.jar:/usr/lib/hadoop/lib/paranamer-2.3.jar:/usr/lib/hadoop/lib/protobuf-java-2.5.0.jar:/usr/lib/hadoop/lib/servlet-api-2.5.jar:/usr/lib/hadoop/lib/snappy-java-1.0.4.1.jar:/usr/lib/hadoop/lib/stax-api-1.0-2.jar:/usr/lib/hadoop/lib/xmlenc-0.52.jar:/usr/lib/hadoop/lib/xz-1.0.jar:/usr/lib/hadoop/lib/zookeeper.jar:/usr/lib/hadoop/.//LICENSE.txt:/usr/lib/hadoop/.//NOTICE.txt:/usr/lib/hadoop/.//bin:/usr/lib/hadoop/.//client:/usr/lib/hadoop/.//client-0.20:/usr/lib/hadoop/.//cloudera:/usr/lib/hadoop/.//etc:/usr/lib/hadoop/.//hadoop-annotations-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-annotations.jar:/usr/lib/hadoop/.//hadoop-auth-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-auth.jar:/usr/lib/hadoop/.//hadoop-aws-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-aws.jar:/usr/lib/hadoop/.//hadoop-common-2.6.0-cdh5.7.0-tests.jar:/usr/lib/hadoop/.//hadoop-common-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-common-tests.jar:/usr/lib/hadoop/.//hadoop-common.jar:/usr/lib/hadoop/.//hadoop-nfs-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-nfs.jar:/usr/lib/hadoop/.//lib:/usr/lib/hadoop/.//libexec:/usr/lib/hadoop/.//parquet-avro.jar:/usr/lib/hadoop/.//parquet-cascading.jar:/usr/lib/hadoop/.//parquet-column.jar:/usr/lib/hadoop/.//parquet-common.jar:/usr/lib/hadoop/.//parquet-enco ...
# 19/05/15 08:45:47 INFO node.PollingPropertiesFileConfigurationProvider: Configuration provider starting
# 19/05/15 08:45:47 INFO node.PollingPropertiesFileConfigurationProvider: Reloading configuration file:/opt/examples/flume/conf/flume-ex1.conf
# 19/05/15 08:45:47 INFO conf.FlumeConfiguration: Processing:sink1
# 19/05/15 08:45:47 INFO conf.FlumeConfiguration: Processing:sink1
# 19/05/15 08:45:47 INFO conf.FlumeConfiguration: Added sinks: sink1 Agent: agent1
# 19/05/15 08:45:47 INFO conf.FlumeConfiguration: Post-validation flume configuration contains configuration for agents: [agent1]
# 19/05/15 08:45:47 INFO node.AbstractConfigurationProvider: Creating channels
# 19/05/15 08:45:47 INFO channel.DefaultChannelFactory: Creating instance of channel channel1 type file
# 19/05/15 08:45:47 INFO node.AbstractConfigurationProvider: Created channel channel1
# 19/05/15 08:45:47 INFO source.DefaultSourceFactory: Creating instance of source source1, type spooldir
# 19/05/15 08:45:47 INFO sink.DefaultSinkFactory: Creating instance of sink: sink1, type: logger
# 19/05/15 08:45:47 INFO node.AbstractConfigurationProvider: Channel channel1 connected to [source1, sink1]
# 19/05/15 08:45:47 INFO node.Application: Starting new configuration:{ sourceRunners:{source1=EventDrivenSourceRunner: { source:Spool Directory source source1: { spoolDir: /tmp/spooldir } }} sinkRunners:{sink1=SinkRunner: { policy:org.apache.flume.sink.DefaultSinkProcessor@3b1e7dd counterGroup:{ name:null counters:{} } }} channels:{channel1=FileChannel channel1 { dataDirs: [/root/.flume/file-channel/data] }} }
# 19/05/15 08:45:47 INFO node.Application: Starting Channel channel1
# 19/05/15 08:45:47 INFO file.FileChannel: Starting FileChannel channel1 { dataDirs: [/root/.flume/file-channel/data] }...
# 19/05/15 08:45:47 INFO file.Log: Encryption is not enabled
# 19/05/15 08:45:47 INFO file.Log: Replay started
# 19/05/15 08:45:47 INFO file.Log: Found NextFileID 4, from [/root/.flume/file-channel/data/log-1, /root/.flume/file-channel/data/log-3, /root/.flume/file-channel/data/log-4, /root/.flume/file-channel/data/log-2]
# 19/05/15 08:45:47 INFO file.EventQueueBackingStoreFileV3: Starting up with /root/.flume/file-channel/checkpoint/checkpoint and /root/.flume/file-channel/checkpoint/checkpoint.meta
# 19/05/15 08:45:47 INFO file.EventQueueBackingStoreFileV3: Reading checkpoint metadata from /root/.flume/file-channel/checkpoint/checkpoint.meta
# 19/05/15 08:45:48 INFO file.FlumeEventQueue: QueueSet population inserting 0 took 0
# 19/05/15 08:45:48 INFO file.Log: Last Checkpoint Wed May 15 08:44:58 UTC 2019, queue depth = 0
# 19/05/15 08:45:48 INFO file.Log: Replaying logs with v2 replay logic
# 19/05/15 08:45:48 INFO file.ReplayHandler: Starting replay of [/root/.flume/file-channel/data/log-1, /root/.flume/file-channel/data/log-2, /root/.flume/file-channel/data/log-3, /root/.flume/file-channel/data/log-4]
# 19/05/15 08:45:48 INFO file.ReplayHandler: Replaying /root/.flume/file-channel/data/log-1
# 19/05/15 08:45:48 INFO tools.DirectMemoryUtils: Unable to get maxDirectMemory from VM: NoSuchMethodException: sun.misc.VM.maxDirectMemory(null)
# 19/05/15 08:45:48 INFO tools.DirectMemoryUtils: Direct Memory Allocation:  Allocation = 1048576, Allocated = 0, MaxDirectMemorySize = 3817865216, Remaining = 3817865216
# 19/05/15 08:45:48 INFO file.LogFile: fast-forward to checkpoint position: 165
# 19/05/15 08:45:48 INFO file.LogFile: Encountered EOF at 165 in /root/.flume/file-channel/data/log-1
# 19/05/15 08:45:48 INFO file.ReplayHandler: Replaying /root/.flume/file-channel/data/log-2
# 19/05/15 08:45:48 INFO file.LogFile: fast-forward to checkpoint position: 187
# 19/05/15 08:45:48 INFO file.LogFile: Encountered EOF at 187 in /root/.flume/file-channel/data/log-2
# 19/05/15 08:45:48 INFO file.ReplayHandler: Replaying /root/.flume/file-channel/data/log-3
# 19/05/15 08:45:48 INFO file.LogFile: Checkpoint for file(/root/.flume/file-channel/data/log-3) is: 1557909736983, which is beyond the requested checkpoint time: 1557909802472 and position 0
# 19/05/15 08:45:48 INFO file.ReplayHandler: Replaying /root/.flume/file-channel/data/log-4
# 19/05/15 08:45:48 INFO file.LogFile: Checkpoint for file(/root/.flume/file-channel/data/log-4) is: 1557909802472, which is beyond the requested checkpoint time: 1557909802472 and position 0
# 19/05/15 08:45:48 INFO file.ReplayHandler: read: 0, put: 0, take: 0, rollback: 0, commit: 0, skip: 0, eventCount:0
# 19/05/15 08:45:48 INFO file.FlumeEventQueue: Search Count = 0, Search Time = 0, Copy Count = 0, Copy Time = 0
# 19/05/15 08:45:48 INFO file.Log: Rolling /root/.flume/file-channel/data
# 19/05/15 08:45:48 INFO file.Log: Roll start /root/.flume/file-channel/data
# 19/05/15 08:45:48 INFO file.LogFile: Opened /root/.flume/file-channel/data/log-5
# 19/05/15 08:45:48 INFO file.Log: Roll end
# 19/05/15 08:45:48 INFO file.EventQueueBackingStoreFile: Start checkpoint for /root/.flume/file-channel/checkpoint/checkpoint, elements to sync = 0
# 19/05/15 08:45:48 INFO file.EventQueueBackingStoreFile: Updating checkpoint metadata: logWriteOrderID: 1557909947975, queueSize: 0, queueHead: 0
# 19/05/15 08:45:48 INFO file.Log: Updated checkpoint for file: /root/.flume/file-channel/data/log-5 position: 0 logWriteOrderID: 1557909947975
# 19/05/15 08:45:48 INFO file.FileChannel: Queue Size after replay: 0 [channel=channel1]
# 19/05/15 08:45:48 INFO instrumentation.MonitoredCounterGroup: Monitored counter group for type: CHANNEL, name: channel1: Successfully registered new MBean.
# 19/05/15 08:45:48 INFO instrumentation.MonitoredCounterGroup: Component type: CHANNEL, name: channel1 started
# 19/05/15 08:45:48 INFO node.Application: Starting Sink sink1
# 19/05/15 08:45:48 INFO node.Application: Starting Source source1
# 19/05/15 08:45:48 INFO source.SpoolDirectorySource: SpoolDirectorySource source starting with directory: /tmp/spooldir
# 19/05/15 08:45:48 INFO instrumentation.MonitoredCounterGroup: Monitored counter group for type: SOURCE, name: source1: Successfully registered new MBean.
# 19/05/15 08:45:48 INFO instrumentation.MonitoredCounterGroup: Component type: SOURCE, name: source1 started
# 19/05/15 08:46:36 INFO avro.ReliableSpoolingFileEventReader: Last read took us just up to a file boundary. Rolling to the next file, if there is one.
# 19/05/15 08:46:36 INFO avro.ReliableSpoolingFileEventReader: Preparing to move file /tmp/spooldir/fileA.txt to /tmp/spooldir/fileA.txt.COMPLETED
# 19/05/15 08:46:38 INFO sink.LoggerSink: Event: { headers:{} body: 41 41 41 41 41 41 41 41 41 41 41 20 70 72 75 65 AAAAAAAAAAA prue }
# 19/05/15 08:46:47 INFO file.EventQueueBackingStoreFile: Start checkpoint for /root/.flume/file-channel/checkpoint/checkpoint, elements to sync = 1
# 19/05/15 08:46:47 INFO file.EventQueueBackingStoreFile: Updating checkpoint metadata: logWriteOrderID: 1557909947980, queueSize: 0, queueHead: 0
# 19/05/15 08:46:47 INFO file.Log: Updated checkpoint for file: /root/.flume/file-channel/data/log-5 position: 175 logWriteOrderID: 1557909947980
# 19/05/15 08:46:47 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-1
# 19/05/15 08:46:47 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-2
# 19/05/15 08:46:47 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-3
# 19/05/15 08:47:09 INFO avro.ReliableSpoolingFileEventReader: Last read took us just up to a file boundary. Rolling to the next file, if there is one.
# 19/05/15 08:47:09 INFO avro.ReliableSpoolingFileEventReader: Preparing to move file /tmp/spooldir/fileB.txt to /tmp/spooldir/fileB.txt.COMPLETED
# 19/05/15 08:47:13 INFO sink.LoggerSink: Event: { headers:{} body: 42 42 42 42 42 42 42 42 42 20 70 72 75 65 62 61 BBBBBBBBB prueba }
# 19/05/15 08:47:17 INFO file.EventQueueBackingStoreFile: Start checkpoint for /root/.flume/file-channel/checkpoint/checkpoint, elements to sync = 1
# 19/05/15 08:47:18 INFO file.EventQueueBackingStoreFile: Updating checkpoint metadata: logWriteOrderID: 1557909947985, queueSize: 0, queueHead: 0
# 19/05/15 08:47:18 INFO file.Log: Updated checkpoint for file: /root/.flume/file-channel/data/log-5 position: 348 logWriteOrderID: 1557909947985
# 19/05/15 08:47:18 INFO file.Log: Removing old file: /root/.flume/file-channel/data/log-1
# 19/05/15 08:47:18 INFO file.Log: Removing old file: /root/.flume/file-channel/data/log-1.meta
# 19/05/15 08:47:18 INFO file.Log: Removing old file: /root/.flume/file-channel/data/log-2
# 19/05/15 08:47:18 INFO file.Log: Removing old file: /root/.flume/file-channel/data/log-2.meta
# 19/05/15 08:47:18 INFO file.Log: Removing old file: /root/.flume/file-channel/data/log-3
# 19/05/15 08:47:18 INFO file.Log: Removing old file: /root/.flume/file-channel/data/log-3.meta
# ^C
# 19/05/15 08:47:22 INFO lifecycle.LifecycleSupervisor: Stopping lifecycle supervisor 10
# 19/05/15 08:47:22 INFO node.PollingPropertiesFileConfigurationProvider: Configuration provider stopping
# 19/05/15 08:47:22 INFO file.FileChannel: Stopping FileChannel channel1 { dataDirs: [/root/.flume/file-channel/data] }...
# 19/05/15 08:47:22 INFO file.EventQueueBackingStoreFile: Start checkpoint for /root/.flume/file-channel/checkpoint/checkpoint, elements to sync = 0
# 19/05/15 08:47:22 INFO file.EventQueueBackingStoreFile: Updating checkpoint metadata: logWriteOrderID: 1557909947986, queueSize: 0, queueHead: 0
# 19/05/15 08:47:22 INFO file.Log: Updated checkpoint for file: /root/.flume/file-channel/data/log-5 position: 348 logWriteOrderID: 1557909947986
# Attempting to shutdown background worker.
# 19/05/15 08:47:22 INFO file.Log: Attempting to shutdown background worker.
# 19/05/15 08:47:22 INFO file.LogFile: Closing /root/.flume/file-channel/data/log-5
# 19/05/15 08:47:22 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-4
# 19/05/15 08:47:22 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-5
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Component type: CHANNEL, name: channel1 stopped
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.start.time == 1557909948202
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.stop.time == 1557910042334
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.capacity == 1000000
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.current.size == 0
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.event.put.attempt == 2
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.event.put.success == 2
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.event.take.attempt == 27
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.event.take.success == 2
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Component type: SOURCE, name: source1 stopped
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. source.start.time == 1557909948221
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. source.stop.time == 1557910042335
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.append-batch.accepted == 2
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.append-batch.received == 2
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.append.accepted == 0
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.append.received == 0
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.events.accepted == 2
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.events.received == 2
# 19/05/15 08:47:22 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.open-connection.count == 0
# 19/05/15 08:47:22 INFO source.SpoolDirectorySource: SpoolDir source source1 stopped. Metrics: SOURCE:source1{src.events.accepted=2, src.events.received=2, src.append.accepted=0, src.append-batch.accepted=2, src.open-connection.count=0, src.append-batch.received=2, src.append.received=0}

# %% [markdown]
# Mientras la celda de arriba se está ejecutando, debemos abrir un terminal y ejecutamos los comandos siguientes:
#
# docker exec -ti CONTAINERID  /bin/bash
#
# echo "AAAAAAAAAAA prueba" > /tmp/spooldir/.fileA.txt
#
# mv /tmp/spooldir/.fileA.txt /tmp/spooldir/fileA.txt
#
# Estas ordenes sirven para crear un /ficherollamado .fileA.txt
# en la ruta indicada y despues lo renombramos a fileA.txt
#
# Repite estas órdenes varias veces cambiando los nombres de los ficheros.
#
# Cuando termines, finaliza el agente parando la celda clicando
# en el boton de stop

# %%
! ls -l  /tmp/spooldir/
# Out:
# total 8
# -rw-r--r-- 1 root root 19 May 15 08:46 fileA.txt.COMPLETED
# -rw-r--r-- 1 root root 17 May 15 08:47 fileB.txt.COMPLETED

# %%
! cat  /tmp/spooldir/fileA.txt.COMPLETED
# Out:
# AAAAAAAAAAA prueba

# %%
# ejecuto el agente. 
# --conf-file /opt/examples/flume/conf/flume-ex1.conf apunta al 
# archivo que hemos escrito unas celdas arriba. 
# --conf /opt/examples/flume/conf apunta al fichero de configuracion 
# de las opciones generales de flume.

! flume-ng agent \
    --conf /opt/examples/flume/conf \
    --conf-file /opt/examples/flume/conf/flume-ex1.conf \
    --name agent1
# Out:
# Info: Sourcing environment configuration script /opt/examples/flume/conf/flume-env.sh
# Info: Including Hadoop libraries found via (/usr/bin/hadoop) for HDFS access
# Info: Excluding /usr/lib/hadoop/lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-log4j12.jar from classpath
# Info: Including HBASE libraries found via (/usr/bin/hbase) for HBASE access
# Info: Excluding /usr/lib/hbase/bin/../lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/hbase/bin/../lib/slf4j-log4j12.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-log4j12.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-log4j12.jar from classpath
# Info: Excluding /usr/lib/zookeeper/lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/zookeeper/lib/slf4j-log4j12-1.7.5.jar from classpath
# Info: Excluding /usr/lib/zookeeper/lib/slf4j-log4j12.jar from classpath
# Info: Including Hive libraries found via () for Hive access
# + exec /usr/java/jdk1.7.0_67-cloudera/bin/java -Xmx4096m -XX:MaxPermSize=256M -cp '/opt/examples/flume/conf:/usr/lib/flume-ng/lib/*:/etc/hadoop/conf:/usr/lib/hadoop/lib/activation-1.1.jar:/usr/lib/hadoop/lib/apacheds-i18n-2.0.0-M15.jar:/usr/lib/hadoop/lib/apacheds-kerberos-codec-2.0.0-M15.jar:/usr/lib/hadoop/lib/api-asn1-api-1.0.0-M20.jar:/usr/lib/hadoop/lib/api-util-1.0.0-M20.jar:/usr/lib/hadoop/lib/asm-3.2.jar:/usr/lib/hadoop/lib/avro.jar:/usr/lib/hadoop/lib/aws-java-sdk-core-1.10.6.jar:/usr/lib/hadoop/lib/aws-java-sdk-kms-1.10.6.jar:/usr/lib/hadoop/lib/aws-java-sdk-s3-1.10.6.jar:/usr/lib/hadoop/lib/commons-beanutils-1.7.0.jar:/usr/lib/hadoop/lib/commons-beanutils-core-1.8.0.jar:/usr/lib/hadoop/lib/commons-cli-1.2.jar:/usr/lib/hadoop/lib/commons-codec-1.4.jar:/usr/lib/hadoop/lib/commons-collections-3.2.2.jar:/usr/lib/hadoop/lib/commons-compress-1.4.1.jar:/usr/lib/hadoop/lib/commons-configuration-1.6.jar:/usr/lib/hadoop/lib/commons-digester-1.8.jar:/usr/lib/hadoop/lib/commons-el-1.0.jar:/usr/lib/hadoop/lib/commons-httpclient-3.1.jar:/usr/lib/hadoop/lib/commons-io-2.4.jar:/usr/lib/hadoop/lib/commons-lang-2.6.jar:/usr/lib/hadoop/lib/commons-logging-1.1.3.jar:/usr/lib/hadoop/lib/commons-math3-3.1.1.jar:/usr/lib/hadoop/lib/commons-net-3.1.jar:/usr/lib/hadoop/lib/curator-client-2.7.1.jar:/usr/lib/hadoop/lib/curator-framework-2.7.1.jar:/usr/lib/hadoop/lib/curator-recipes-2.7.1.jar:/usr/lib/hadoop/lib/gson-2.2.4.jar:/usr/lib/hadoop/lib/guava-11.0.2.jar:/usr/lib/hadoop/lib/hamcrest-core-1.3.jar:/usr/lib/hadoop/lib/htrace-core4-4.0.1-incubating.jar:/usr/lib/hadoop/lib/httpclient-4.2.5.jar:/usr/lib/hadoop/lib/httpcore-4.2.5.jar:/usr/lib/hadoop/lib/hue-plugins-3.9.0-cdh5.7.0.jar:/usr/lib/hadoop/lib/jackson-core-asl-1.8.8.jar:/usr/lib/hadoop/lib/jackson-jaxrs-1.8.8.jar:/usr/lib/hadoop/lib/jackson-mapper-asl-1.8.8.jar:/usr/lib/hadoop/lib/jackson-xc-1.8.8.jar:/usr/lib/hadoop/lib/jasper-compiler-5.5.23.jar:/usr/lib/hadoop/lib/jasper-runtime-5.5.23.jar:/usr/lib/hadoop/lib/java-xmlbuilder-0.4.jar:/usr/lib/hadoop/lib/jaxb-api-2.2.2.jar:/usr/lib/hadoop/lib/jaxb-impl-2.2.3-1.jar:/usr/lib/hadoop/lib/jersey-core-1.9.jar:/usr/lib/hadoop/lib/jersey-json-1.9.jar:/usr/lib/hadoop/lib/jersey-server-1.9.jar:/usr/lib/hadoop/lib/jets3t-0.9.0.jar:/usr/lib/hadoop/lib/jettison-1.1.jar:/usr/lib/hadoop/lib/jetty-6.1.26.cloudera.4.jar:/usr/lib/hadoop/lib/jetty-util-6.1.26.cloudera.4.jar:/usr/lib/hadoop/lib/jsch-0.1.42.jar:/usr/lib/hadoop/lib/jsp-api-2.1.jar:/usr/lib/hadoop/lib/jsr305-3.0.0.jar:/usr/lib/hadoop/lib/junit-4.11.jar:/usr/lib/hadoop/lib/log4j-1.2.17.jar:/usr/lib/hadoop/lib/logredactor-1.0.3.jar:/usr/lib/hadoop/lib/mockito-all-1.8.5.jar:/usr/lib/hadoop/lib/native:/usr/lib/hadoop/lib/netty-3.6.2.Final.jar:/usr/lib/hadoop/lib/paranamer-2.3.jar:/usr/lib/hadoop/lib/protobuf-java-2.5.0.jar:/usr/lib/hadoop/lib/servlet-api-2.5.jar:/usr/lib/hadoop/lib/snappy-java-1.0.4.1.jar:/usr/lib/hadoop/lib/stax-api-1.0-2.jar:/usr/lib/hadoop/lib/xmlenc-0.52.jar:/usr/lib/hadoop/lib/xz-1.0.jar:/usr/lib/hadoop/lib/zookeeper.jar:/usr/lib/hadoop/.//LICENSE.txt:/usr/lib/hadoop/.//NOTICE.txt:/usr/lib/hadoop/.//bin:/usr/lib/hadoop/.//client:/usr/lib/hadoop/.//client-0.20:/usr/lib/hadoop/.//cloudera:/usr/lib/hadoop/.//etc:/usr/lib/hadoop/.//hadoop-annotations-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-annotations.jar:/usr/lib/hadoop/.//hadoop-auth-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-auth.jar:/usr/lib/hadoop/.//hadoop-aws-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-aws.jar:/usr/lib/hadoop/.//hadoop-common-2.6.0-cdh5.7.0-tests.jar:/usr/lib/hadoop/.//hadoop-common-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-common-tests.jar:/usr/lib/hadoop/.//hadoop-common.jar:/usr/lib/hadoop/.//hadoop-nfs-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-nfs.jar:/usr/lib/hadoop/.//lib:/usr/lib/hadoop/.//libexec:/usr/lib/hadoop/.//parquet-avro.jar:/usr/lib/hadoop/.//parquet-cascading.jar:/usr/lib/hadoop/.//parquet-column.jar:/usr/lib/hadoop/.//parquet-common.jar:/usr/lib/hadoop/.//parquet-enco ...
# 19/05/15 08:50:01 INFO node.PollingPropertiesFileConfigurationProvider: Configuration provider starting
# 19/05/15 08:50:01 INFO node.PollingPropertiesFileConfigurationProvider: Reloading configuration file:/opt/examples/flume/conf/flume-ex1.conf
# 19/05/15 08:50:01 INFO conf.FlumeConfiguration: Processing:sink1
# 19/05/15 08:50:01 INFO conf.FlumeConfiguration: Processing:sink1
# 19/05/15 08:50:01 INFO conf.FlumeConfiguration: Added sinks: sink1 Agent: agent1
# 19/05/15 08:50:01 INFO conf.FlumeConfiguration: Post-validation flume configuration contains configuration for agents: [agent1]
# 19/05/15 08:50:01 INFO node.AbstractConfigurationProvider: Creating channels
# 19/05/15 08:50:01 INFO channel.DefaultChannelFactory: Creating instance of channel channel1 type file
# 19/05/15 08:50:01 INFO node.AbstractConfigurationProvider: Created channel channel1
# 19/05/15 08:50:01 INFO source.DefaultSourceFactory: Creating instance of source source1, type spooldir
# 19/05/15 08:50:01 INFO sink.DefaultSinkFactory: Creating instance of sink: sink1, type: logger
# 19/05/15 08:50:01 INFO node.AbstractConfigurationProvider: Channel channel1 connected to [source1, sink1]
# 19/05/15 08:50:01 INFO node.Application: Starting new configuration:{ sourceRunners:{source1=EventDrivenSourceRunner: { source:Spool Directory source source1: { spoolDir: /tmp/spooldir } }} sinkRunners:{sink1=SinkRunner: { policy:org.apache.flume.sink.DefaultSinkProcessor@14ed6010 counterGroup:{ name:null counters:{} } }} channels:{channel1=FileChannel channel1 { dataDirs: [/root/.flume/file-channel/data] }} }
# 19/05/15 08:50:01 INFO node.Application: Starting Channel channel1
# 19/05/15 08:50:01 INFO file.FileChannel: Starting FileChannel channel1 { dataDirs: [/root/.flume/file-channel/data] }...
# 19/05/15 08:50:01 INFO file.Log: Encryption is not enabled
# 19/05/15 08:50:01 INFO file.Log: Replay started
# 19/05/15 08:50:02 INFO file.Log: Found NextFileID 5, from [/root/.flume/file-channel/data/log-5, /root/.flume/file-channel/data/log-4]
# 19/05/15 08:50:02 INFO file.EventQueueBackingStoreFileV3: Starting up with /root/.flume/file-channel/checkpoint/checkpoint and /root/.flume/file-channel/checkpoint/checkpoint.meta
# 19/05/15 08:50:02 INFO file.EventQueueBackingStoreFileV3: Reading checkpoint metadata from /root/.flume/file-channel/checkpoint/checkpoint.meta
# 19/05/15 08:50:02 INFO file.FlumeEventQueue: QueueSet population inserting 0 took 0
# 19/05/15 08:50:02 INFO file.Log: Last Checkpoint Wed May 15 08:47:22 UTC 2019, queue depth = 0
# 19/05/15 08:50:02 INFO file.Log: Replaying logs with v2 replay logic
# 19/05/15 08:50:02 INFO file.ReplayHandler: Starting replay of [/root/.flume/file-channel/data/log-4, /root/.flume/file-channel/data/log-5]
# 19/05/15 08:50:02 INFO file.ReplayHandler: Replaying /root/.flume/file-channel/data/log-4
# 19/05/15 08:50:02 INFO tools.DirectMemoryUtils: Unable to get maxDirectMemory from VM: NoSuchMethodException: sun.misc.VM.maxDirectMemory(null)
# 19/05/15 08:50:02 INFO tools.DirectMemoryUtils: Direct Memory Allocation:  Allocation = 1048576, Allocated = 0, MaxDirectMemorySize = 3817865216, Remaining = 3817865216
# 19/05/15 08:50:02 INFO file.LogFile: Checkpoint for file(/root/.flume/file-channel/data/log-4) is: 1557909802472, which is beyond the requested checkpoint time: 1557909947986 and position 0
# 19/05/15 08:50:02 INFO file.ReplayHandler: Replaying /root/.flume/file-channel/data/log-5
# 19/05/15 08:50:02 INFO file.LogFile: fast-forward to checkpoint position: 348
# 19/05/15 08:50:02 INFO file.LogFile: Encountered EOF at 348 in /root/.flume/file-channel/data/log-5
# 19/05/15 08:50:02 INFO file.ReplayHandler: read: 0, put: 0, take: 0, rollback: 0, commit: 0, skip: 0, eventCount:0
# 19/05/15 08:50:02 INFO file.FlumeEventQueue: Search Count = 0, Search Time = 0, Copy Count = 0, Copy Time = 0
# 19/05/15 08:50:02 INFO file.Log: Rolling /root/.flume/file-channel/data
# 19/05/15 08:50:02 INFO file.Log: Roll start /root/.flume/file-channel/data
# 19/05/15 08:50:02 INFO file.LogFile: Opened /root/.flume/file-channel/data/log-6
# 19/05/15 08:50:02 INFO file.Log: Roll end
# 19/05/15 08:50:02 INFO file.EventQueueBackingStoreFile: Start checkpoint for /root/.flume/file-channel/checkpoint/checkpoint, elements to sync = 0
# 19/05/15 08:50:02 INFO file.EventQueueBackingStoreFile: Updating checkpoint metadata: logWriteOrderID: 1557910202030, queueSize: 0, queueHead: 0
# 19/05/15 08:50:02 INFO file.Log: Updated checkpoint for file: /root/.flume/file-channel/data/log-6 position: 0 logWriteOrderID: 1557910202030
# 19/05/15 08:50:02 INFO file.FileChannel: Queue Size after replay: 0 [channel=channel1]
# 19/05/15 08:50:02 INFO instrumentation.MonitoredCounterGroup: Monitored counter group for type: CHANNEL, name: channel1: Successfully registered new MBean.
# 19/05/15 08:50:02 INFO instrumentation.MonitoredCounterGroup: Component type: CHANNEL, name: channel1 started
# 19/05/15 08:50:02 INFO node.Application: Starting Sink sink1
# 19/05/15 08:50:02 INFO node.Application: Starting Source source1
# 19/05/15 08:50:02 INFO source.SpoolDirectorySource: SpoolDirectorySource source starting with directory: /tmp/spooldir
# 19/05/15 08:50:02 INFO instrumentation.MonitoredCounterGroup: Monitored counter group for type: SOURCE, name: source1: Successfully registered new MBean.
# 19/05/15 08:50:02 INFO instrumentation.MonitoredCounterGroup: Component type: SOURCE, name: source1 started
# 19/05/15 08:50:29 INFO avro.ReliableSpoolingFileEventReader: Last read took us just up to a file boundary. Rolling to the next file, if there is one.
# 19/05/15 08:50:29 INFO avro.ReliableSpoolingFileEventReader: Preparing to move file /tmp/spooldir/fileC.txt to /tmp/spooldir/fileC.txt.COMPLETED
# 19/05/15 08:50:31 INFO file.EventQueueBackingStoreFile: Start checkpoint for /root/.flume/file-channel/checkpoint/checkpoint, elements to sync = 1
# 19/05/15 08:50:32 INFO file.EventQueueBackingStoreFile: Updating checkpoint metadata: logWriteOrderID: 1557910202033, queueSize: 1, queueHead: 999999
# 19/05/15 08:50:32 INFO file.Log: Updated checkpoint for file: /root/.flume/file-channel/data/log-6 position: 94 logWriteOrderID: 1557910202033
# 19/05/15 08:50:32 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-4
# 19/05/15 08:50:32 INFO sink.LoggerSink: Event: { headers:{} body: 43 43 43 43 43 43 43 20 70 72 75 65 62 61       CCCCCCC prueba }
# 19/05/15 08:51:02 INFO file.EventQueueBackingStoreFile: Start checkpoint for /root/.flume/file-channel/checkpoint/checkpoint, elements to sync = 1
# 19/05/15 08:51:02 INFO file.EventQueueBackingStoreFile: Updating checkpoint metadata: logWriteOrderID: 1557910202036, queueSize: 0, queueHead: 0
# 19/05/15 08:51:02 INFO file.Log: Updated checkpoint for file: /root/.flume/file-channel/data/log-6 position: 171 logWriteOrderID: 1557910202036
# 19/05/15 08:51:02 INFO file.Log: Removing old file: /root/.flume/file-channel/data/log-4
# 19/05/15 08:51:02 INFO file.Log: Removing old file: /root/.flume/file-channel/data/log-4.meta
# 19/05/15 08:58:54 INFO avro.ReliableSpoolingFileEventReader: Last read took us just up to a file boundary. Rolling to the next file, if there is one.
# 19/05/15 08:58:54 INFO avro.ReliableSpoolingFileEventReader: Preparing to move file /tmp/spooldir/fileD.txt to /tmp/spooldir/fileD.txt.COMPLETED
# 19/05/15 08:58:57 INFO sink.LoggerSink: Event: { headers:{} body: 44 44 44 44 44 44 44 20 70 72 75 65 62 61       DDDDDDD prueba }
# 19/05/15 08:59:02 INFO file.EventQueueBackingStoreFile: Start checkpoint for /root/.flume/file-channel/checkpoint/checkpoint, elements to sync = 1
# 19/05/15 08:59:02 INFO file.EventQueueBackingStoreFile: Updating checkpoint metadata: logWriteOrderID: 1557910202041, queueSize: 0, queueHead: 0
# 19/05/15 08:59:02 INFO file.Log: Updated checkpoint for file: /root/.flume/file-channel/data/log-6 position: 342 logWriteOrderID: 1557910202041
# ^C
# 19/05/15 09:01:05 INFO lifecycle.LifecycleSupervisor: Stopping lifecycle supervisor 10
# 19/05/15 09:01:05 INFO node.PollingPropertiesFileConfigurationProvider: Configuration provider stopping
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Component type: SOURCE, name: source1 stopped
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. source.start.time == 1557910202322
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. source.stop.time == 1557910865845
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.append-batch.accepted == 2
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.append-batch.received == 2
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.append.accepted == 0
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.append.received == 0
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.events.accepted == 2
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.events.received == 2
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.open-connection.count == 0
# 19/05/15 09:01:05 INFO source.SpoolDirectorySource: SpoolDir source source1 stopped. Metrics: SOURCE:source1{src.events.accepted=2, src.events.received=2, src.append.accepted=0, src.append-batch.accepted=2, src.open-connection.count=0, src.append-batch.received=2, src.append.received=0}
# 19/05/15 09:01:05 INFO file.FileChannel: Stopping FileChannel channel1 { dataDirs: [/root/.flume/file-channel/data] }...
# 19/05/15 09:01:05 INFO file.EventQueueBackingStoreFile: Start checkpoint for /root/.flume/file-channel/checkpoint/checkpoint, elements to sync = 0
# 19/05/15 09:01:05 INFO file.EventQueueBackingStoreFile: Updating checkpoint metadata: logWriteOrderID: 1557910202042, queueSize: 0, queueHead: 0
# 19/05/15 09:01:05 INFO file.Log: Updated checkpoint for file: /root/.flume/file-channel/data/log-6 position: 342 logWriteOrderID: 1557910202042
# Attempting to shutdown background worker.
# 19/05/15 09:01:05 INFO file.Log: Attempting to shutdown background worker.
# 19/05/15 09:01:05 INFO file.LogFile: Closing /root/.flume/file-channel/data/log-6
# 19/05/15 09:01:05 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-5
# 19/05/15 09:01:05 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-6
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Component type: CHANNEL, name: channel1 stopped
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.start.time == 1557910202303
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.stop.time == 1557910865885
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.capacity == 1000000
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.current.size == 0
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.event.put.attempt == 2
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.event.put.success == 2
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.event.take.attempt == 141
# 19/05/15 09:01:05 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.event.take.success == 2

# %% [markdown]
# ## Ejercicio propuesto
#
# Modifica el ejercicio anterior para que el sink sea HDFS, de forma que se escriban los datos en la carpeta /user/cloudera/ejflumehdfs.
#
# En las transparencias del tema tenemos los parametros de configuración del sink HDFS (en negrita los obligatorios) Ademas de los obligatorios, es necesario incluir los parametros necesarios para que el fichero sea de tipo DataStream y el formato de escritura sea Text (este último es el parametro writeFormat). Todos estos parametros se deben incluir en el fichero /opt/examples/flume/conf/flume-ex1.conf que hemos creado anteriormente. Tras modificar este fichero, procederemos a ejecutar otra vez el agente y a repetir los pasos de creación del fichero en el terminal.
#
# Para una descripción más detallada de los parámetros de configuración del sink HDFS, se encuentra en el siguiente enlace (es necesario estar logado en UNED para poder acceder):
#
#
#
# https://www.oreilly.com/library/view/using-flume/9781491905326/

# %%
! hadoop fs -mkdir  /user/cloudera/ejflumehdfs

# %%
# %%writefile /opt/examples/flume/conf/flume-ex1.conf
# # En primer lugar definimos los componentes princpales (source, channel, sink).
# # agent1 es el nombre de mi agente, lo tendre que utilizar en la orden para ejecutarlo (en algunas celdas mas abajo)
# agent1.sources = source1
# agent1.sinks = sink1
# agent1.channels = channel1
#
# # Enlazo mis componentes source - channel- sink
# agent1.sources.source1.channels = channel1
# agent1.sinks.sink1.channel = channel1
#
# # Configuro cada componente. Primero el source, de tipo spooldir,
# # le tenemos que indicar el directorio que vamos a utilizar
# agent1.sources.source1.type = spooldir
# agent1.sources.source1.spoolDir = /tmp/spooldir
#
# # Ahora configuramos el sink, de tipo hdfs.
#
# # TU CODIGO AQUI
# agent1.sinks.sink1.type = hdfs
# agent1.sinks.sink1.hdfs.path = /user/cloudera/ejflumehdfs
# agent1.sinks.sink1.hdfs.fileType = DataStream
# agent1.sinks.sink1.hdfs.writeFormat = Text
#
#
# # Ahora el channel, de tipo file
# agent1.channels.channel1.type = file
# Out:
# Overwriting /opt/examples/flume/conf/flume-ex1.conf

# %%
# ejecuto el agente. 
# --conf-file /opt/examples/flume/conf/flume-ex1.conf apunta al archivo 
# que hemos escrito unas celdas arriba. 
# --conf /opt/examples/flume/conf apunta al fichero de configuracion 
# de las opciones generales de flume.

! flume-ng agent \
    --conf /opt/examples/flume/conf \
    --conf-file /opt/examples/flume/conf/flume-ex1.conf \
    --name agent1
# Out:
# Info: Sourcing environment configuration script /opt/examples/flume/conf/flume-env.sh
# Info: Including Hadoop libraries found via (/usr/bin/hadoop) for HDFS access
# Info: Excluding /usr/lib/hadoop/lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-log4j12.jar from classpath
# Info: Including HBASE libraries found via (/usr/bin/hbase) for HBASE access
# Info: Excluding /usr/lib/hbase/bin/../lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/hbase/bin/../lib/slf4j-log4j12.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-log4j12.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/hadoop/lib/slf4j-log4j12.jar from classpath
# Info: Excluding /usr/lib/zookeeper/lib/slf4j-api-1.7.5.jar from classpath
# Info: Excluding /usr/lib/zookeeper/lib/slf4j-log4j12-1.7.5.jar from classpath
# Info: Excluding /usr/lib/zookeeper/lib/slf4j-log4j12.jar from classpath
# Info: Including Hive libraries found via () for Hive access
# + exec /usr/java/jdk1.7.0_67-cloudera/bin/java -Xmx4096m -XX:MaxPermSize=256M -cp '/opt/examples/flume/conf:/usr/lib/flume-ng/lib/*:/etc/hadoop/conf:/usr/lib/hadoop/lib/activation-1.1.jar:/usr/lib/hadoop/lib/apacheds-i18n-2.0.0-M15.jar:/usr/lib/hadoop/lib/apacheds-kerberos-codec-2.0.0-M15.jar:/usr/lib/hadoop/lib/api-asn1-api-1.0.0-M20.jar:/usr/lib/hadoop/lib/api-util-1.0.0-M20.jar:/usr/lib/hadoop/lib/asm-3.2.jar:/usr/lib/hadoop/lib/avro.jar:/usr/lib/hadoop/lib/aws-java-sdk-core-1.10.6.jar:/usr/lib/hadoop/lib/aws-java-sdk-kms-1.10.6.jar:/usr/lib/hadoop/lib/aws-java-sdk-s3-1.10.6.jar:/usr/lib/hadoop/lib/commons-beanutils-1.7.0.jar:/usr/lib/hadoop/lib/commons-beanutils-core-1.8.0.jar:/usr/lib/hadoop/lib/commons-cli-1.2.jar:/usr/lib/hadoop/lib/commons-codec-1.4.jar:/usr/lib/hadoop/lib/commons-collections-3.2.2.jar:/usr/lib/hadoop/lib/commons-compress-1.4.1.jar:/usr/lib/hadoop/lib/commons-configuration-1.6.jar:/usr/lib/hadoop/lib/commons-digester-1.8.jar:/usr/lib/hadoop/lib/commons-el-1.0.jar:/usr/lib/hadoop/lib/commons-httpclient-3.1.jar:/usr/lib/hadoop/lib/commons-io-2.4.jar:/usr/lib/hadoop/lib/commons-lang-2.6.jar:/usr/lib/hadoop/lib/commons-logging-1.1.3.jar:/usr/lib/hadoop/lib/commons-math3-3.1.1.jar:/usr/lib/hadoop/lib/commons-net-3.1.jar:/usr/lib/hadoop/lib/curator-client-2.7.1.jar:/usr/lib/hadoop/lib/curator-framework-2.7.1.jar:/usr/lib/hadoop/lib/curator-recipes-2.7.1.jar:/usr/lib/hadoop/lib/gson-2.2.4.jar:/usr/lib/hadoop/lib/guava-11.0.2.jar:/usr/lib/hadoop/lib/hamcrest-core-1.3.jar:/usr/lib/hadoop/lib/htrace-core4-4.0.1-incubating.jar:/usr/lib/hadoop/lib/httpclient-4.2.5.jar:/usr/lib/hadoop/lib/httpcore-4.2.5.jar:/usr/lib/hadoop/lib/hue-plugins-3.9.0-cdh5.7.0.jar:/usr/lib/hadoop/lib/jackson-core-asl-1.8.8.jar:/usr/lib/hadoop/lib/jackson-jaxrs-1.8.8.jar:/usr/lib/hadoop/lib/jackson-mapper-asl-1.8.8.jar:/usr/lib/hadoop/lib/jackson-xc-1.8.8.jar:/usr/lib/hadoop/lib/jasper-compiler-5.5.23.jar:/usr/lib/hadoop/lib/jasper-runtime-5.5.23.jar:/usr/lib/hadoop/lib/java-xmlbuilder-0.4.jar:/usr/lib/hadoop/lib/jaxb-api-2.2.2.jar:/usr/lib/hadoop/lib/jaxb-impl-2.2.3-1.jar:/usr/lib/hadoop/lib/jersey-core-1.9.jar:/usr/lib/hadoop/lib/jersey-json-1.9.jar:/usr/lib/hadoop/lib/jersey-server-1.9.jar:/usr/lib/hadoop/lib/jets3t-0.9.0.jar:/usr/lib/hadoop/lib/jettison-1.1.jar:/usr/lib/hadoop/lib/jetty-6.1.26.cloudera.4.jar:/usr/lib/hadoop/lib/jetty-util-6.1.26.cloudera.4.jar:/usr/lib/hadoop/lib/jsch-0.1.42.jar:/usr/lib/hadoop/lib/jsp-api-2.1.jar:/usr/lib/hadoop/lib/jsr305-3.0.0.jar:/usr/lib/hadoop/lib/junit-4.11.jar:/usr/lib/hadoop/lib/log4j-1.2.17.jar:/usr/lib/hadoop/lib/logredactor-1.0.3.jar:/usr/lib/hadoop/lib/mockito-all-1.8.5.jar:/usr/lib/hadoop/lib/native:/usr/lib/hadoop/lib/netty-3.6.2.Final.jar:/usr/lib/hadoop/lib/paranamer-2.3.jar:/usr/lib/hadoop/lib/protobuf-java-2.5.0.jar:/usr/lib/hadoop/lib/servlet-api-2.5.jar:/usr/lib/hadoop/lib/snappy-java-1.0.4.1.jar:/usr/lib/hadoop/lib/stax-api-1.0-2.jar:/usr/lib/hadoop/lib/xmlenc-0.52.jar:/usr/lib/hadoop/lib/xz-1.0.jar:/usr/lib/hadoop/lib/zookeeper.jar:/usr/lib/hadoop/.//LICENSE.txt:/usr/lib/hadoop/.//NOTICE.txt:/usr/lib/hadoop/.//bin:/usr/lib/hadoop/.//client:/usr/lib/hadoop/.//client-0.20:/usr/lib/hadoop/.//cloudera:/usr/lib/hadoop/.//etc:/usr/lib/hadoop/.//hadoop-annotations-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-annotations.jar:/usr/lib/hadoop/.//hadoop-auth-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-auth.jar:/usr/lib/hadoop/.//hadoop-aws-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-aws.jar:/usr/lib/hadoop/.//hadoop-common-2.6.0-cdh5.7.0-tests.jar:/usr/lib/hadoop/.//hadoop-common-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-common-tests.jar:/usr/lib/hadoop/.//hadoop-common.jar:/usr/lib/hadoop/.//hadoop-nfs-2.6.0-cdh5.7.0.jar:/usr/lib/hadoop/.//hadoop-nfs.jar:/usr/lib/hadoop/.//lib:/usr/lib/hadoop/.//libexec:/usr/lib/hadoop/.//parquet-avro.jar:/usr/lib/hadoop/.//parquet-cascading.jar:/usr/lib/hadoop/.//parquet-column.jar:/usr/lib/hadoop/.//parquet-common.jar:/usr/lib/hadoop/.//parquet-enco ...
# 19/05/15 09:03:23 INFO node.PollingPropertiesFileConfigurationProvider: Configuration provider starting
# 19/05/15 09:03:23 INFO node.PollingPropertiesFileConfigurationProvider: Reloading configuration file:/opt/examples/flume/conf/flume-ex1.conf
# 19/05/15 09:03:23 INFO conf.FlumeConfiguration: Processing:sink1
# 19/05/15 09:03:23 INFO conf.FlumeConfiguration: Processing:sink1
# 19/05/15 09:03:23 INFO conf.FlumeConfiguration: Processing:sink1
# 19/05/15 09:03:23 INFO conf.FlumeConfiguration: Processing:sink1
# 19/05/15 09:03:23 INFO conf.FlumeConfiguration: Added sinks: sink1 Agent: agent1
# 19/05/15 09:03:23 INFO conf.FlumeConfiguration: Processing:sink1
# 19/05/15 09:03:23 INFO conf.FlumeConfiguration: Post-validation flume configuration contains configuration for agents: [agent1]
# 19/05/15 09:03:23 INFO node.AbstractConfigurationProvider: Creating channels
# 19/05/15 09:03:23 INFO channel.DefaultChannelFactory: Creating instance of channel channel1 type file
# 19/05/15 09:03:24 INFO node.AbstractConfigurationProvider: Created channel channel1
# 19/05/15 09:03:24 INFO source.DefaultSourceFactory: Creating instance of source source1, type spooldir
# 19/05/15 09:03:24 INFO sink.DefaultSinkFactory: Creating instance of sink: sink1, type: hdfs
# 19/05/15 09:03:24 INFO node.AbstractConfigurationProvider: Channel channel1 connected to [source1, sink1]
# 19/05/15 09:03:24 INFO node.Application: Starting new configuration:{ sourceRunners:{source1=EventDrivenSourceRunner: { source:Spool Directory source source1: { spoolDir: /tmp/spooldir } }} sinkRunners:{sink1=SinkRunner: { policy:org.apache.flume.sink.DefaultSinkProcessor@391fc13d counterGroup:{ name:null counters:{} } }} channels:{channel1=FileChannel channel1 { dataDirs: [/root/.flume/file-channel/data] }} }
# 19/05/15 09:03:24 INFO node.Application: Starting Channel channel1
# 19/05/15 09:03:24 INFO file.FileChannel: Starting FileChannel channel1 { dataDirs: [/root/.flume/file-channel/data] }...
# 19/05/15 09:03:24 INFO file.Log: Encryption is not enabled
# 19/05/15 09:03:24 INFO file.Log: Replay started
# 19/05/15 09:03:24 INFO file.Log: Found NextFileID 8, from [/root/.flume/file-channel/data/log-6, /root/.flume/file-channel/data/log-8, /root/.flume/file-channel/data/log-5, /root/.flume/file-channel/data/log-7]
# 19/05/15 09:03:24 INFO file.EventQueueBackingStoreFileV3: Starting up with /root/.flume/file-channel/checkpoint/checkpoint and /root/.flume/file-channel/checkpoint/checkpoint.meta
# 19/05/15 09:03:24 INFO file.EventQueueBackingStoreFileV3: Reading checkpoint metadata from /root/.flume/file-channel/checkpoint/checkpoint.meta
# 19/05/15 09:03:24 INFO file.FlumeEventQueue: QueueSet population inserting 0 took 0
# 19/05/15 09:03:24 INFO file.Log: Last Checkpoint Wed May 15 09:02:37 UTC 2019, queue depth = 0
# 19/05/15 09:03:24 INFO file.Log: Replaying logs with v2 replay logic
# 19/05/15 09:03:24 INFO file.ReplayHandler: Starting replay of [/root/.flume/file-channel/data/log-5, /root/.flume/file-channel/data/log-6, /root/.flume/file-channel/data/log-7, /root/.flume/file-channel/data/log-8]
# 19/05/15 09:03:24 INFO file.ReplayHandler: Replaying /root/.flume/file-channel/data/log-5
# 19/05/15 09:03:24 INFO tools.DirectMemoryUtils: Unable to get maxDirectMemory from VM: NoSuchMethodException: sun.misc.VM.maxDirectMemory(null)
# 19/05/15 09:03:24 INFO tools.DirectMemoryUtils: Direct Memory Allocation:  Allocation = 1048576, Allocated = 0, MaxDirectMemorySize = 3817865216, Remaining = 3817865216
# 19/05/15 09:03:24 INFO file.LogFile: fast-forward to checkpoint position: 348
# 19/05/15 09:03:24 INFO file.LogFile: Encountered EOF at 348 in /root/.flume/file-channel/data/log-5
# 19/05/15 09:03:24 INFO file.ReplayHandler: Replaying /root/.flume/file-channel/data/log-6
# 19/05/15 09:03:24 INFO file.LogFile: fast-forward to checkpoint position: 342
# 19/05/15 09:03:24 INFO file.LogFile: Encountered EOF at 342 in /root/.flume/file-channel/data/log-6
# 19/05/15 09:03:24 INFO file.ReplayHandler: Replaying /root/.flume/file-channel/data/log-7
# 19/05/15 09:03:24 INFO file.LogFile: Checkpoint for file(/root/.flume/file-channel/data/log-7) is: 1557910871955, which is beyond the requested checkpoint time: 1557910910443 and position 0
# 19/05/15 09:03:24 INFO file.ReplayHandler: Replaying /root/.flume/file-channel/data/log-8
# 19/05/15 09:03:24 INFO file.LogFile: fast-forward to checkpoint position: 173
# 19/05/15 09:03:24 INFO file.LogFile: Encountered EOF at 173 in /root/.flume/file-channel/data/log-8
# 19/05/15 09:03:24 INFO file.ReplayHandler: read: 0, put: 0, take: 0, rollback: 0, commit: 0, skip: 0, eventCount:0
# 19/05/15 09:03:24 INFO file.FlumeEventQueue: Search Count = 0, Search Time = 0, Copy Count = 0, Copy Time = 0
# 19/05/15 09:03:24 INFO file.Log: Rolling /root/.flume/file-channel/data
# 19/05/15 09:03:24 INFO file.Log: Roll start /root/.flume/file-channel/data
# 19/05/15 09:03:24 INFO file.LogFile: Opened /root/.flume/file-channel/data/log-9
# 19/05/15 09:03:24 INFO file.Log: Roll end
# 19/05/15 09:03:24 INFO file.EventQueueBackingStoreFile: Start checkpoint for /root/.flume/file-channel/checkpoint/checkpoint, elements to sync = 0
# 19/05/15 09:03:24 INFO file.EventQueueBackingStoreFile: Updating checkpoint metadata: logWriteOrderID: 1557911004120, queueSize: 0, queueHead: 0
# 19/05/15 09:03:24 INFO file.Log: Updated checkpoint for file: /root/.flume/file-channel/data/log-9 position: 0 logWriteOrderID: 1557911004120
# 19/05/15 09:03:24 INFO file.FileChannel: Queue Size after replay: 0 [channel=channel1]
# 19/05/15 09:03:24 INFO instrumentation.MonitoredCounterGroup: Monitored counter group for type: CHANNEL, name: channel1: Successfully registered new MBean.
# 19/05/15 09:03:24 INFO instrumentation.MonitoredCounterGroup: Component type: CHANNEL, name: channel1 started
# 19/05/15 09:03:24 INFO node.Application: Waiting for channel: channel1 to start. Sleeping for 500 ms
# 19/05/15 09:03:24 INFO node.Application: Starting Sink sink1
# 19/05/15 09:03:24 INFO instrumentation.MonitoredCounterGroup: Monitored counter group for type: SINK, name: sink1: Successfully registered new MBean.
# 19/05/15 09:03:24 INFO instrumentation.MonitoredCounterGroup: Component type: SINK, name: sink1 started
# 19/05/15 09:03:24 INFO node.Application: Starting Source source1
# 19/05/15 09:03:24 INFO source.SpoolDirectorySource: SpoolDirectorySource source starting with directory: /tmp/spooldir
# 19/05/15 09:03:24 INFO instrumentation.MonitoredCounterGroup: Monitored counter group for type: SOURCE, name: source1: Successfully registered new MBean.
# 19/05/15 09:03:24 INFO instrumentation.MonitoredCounterGroup: Component type: SOURCE, name: source1 started
# 19/05/15 09:03:44 INFO avro.ReliableSpoolingFileEventReader: Last read took us just up to a file boundary. Rolling to the next file, if there is one.
# 19/05/15 09:03:44 INFO avro.ReliableSpoolingFileEventReader: Preparing to move file /tmp/spooldir/fileF.txt to /tmp/spooldir/fileF.txt.COMPLETED
# 19/05/15 09:03:44 INFO hdfs.HDFSDataStream: Serializer = TEXT, UseRawLocalFileSystem = false
# 19/05/15 09:03:45 INFO hdfs.BucketWriter: Creating /user/cloudera/ejflumehdfs/FlumeData.1557911024881.tmp
# 19/05/15 09:03:54 INFO file.EventQueueBackingStoreFile: Start checkpoint for /root/.flume/file-channel/checkpoint/checkpoint, elements to sync = 1
# 19/05/15 09:03:54 INFO file.EventQueueBackingStoreFile: Updating checkpoint metadata: logWriteOrderID: 1557911004125, queueSize: 0, queueHead: 0
# 19/05/15 09:03:54 INFO file.Log: Updated checkpoint for file: /root/.flume/file-channel/data/log-9 position: 172 logWriteOrderID: 1557911004125
# 19/05/15 09:03:54 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-5
# 19/05/15 09:03:54 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-6
# 19/05/15 09:03:54 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-7
# ^C
# 19/05/15 09:04:06 INFO lifecycle.LifecycleSupervisor: Stopping lifecycle supervisor 10
# 19/05/15 09:04:06 INFO hdfs.HDFSEventSink: Closing /user/cloudera/ejflumehdfs/FlumeData
# 19/05/15 09:04:06 INFO hdfs.BucketWriter: Closing /user/cloudera/ejflumehdfs/FlumeData.1557911024881.tmp
# 19/05/15 09:04:06 INFO hdfs.BucketWriter: Renaming /user/cloudera/ejflumehdfs/FlumeData.1557911024881.tmp to /user/cloudera/ejflumehdfs/FlumeData.1557911024881
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Component type: SINK, name: sink1 stopped
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SINK, name: sink1. sink.start.time == 1557911004866
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SINK, name: sink1. sink.stop.time == 1557911046328
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SINK, name: sink1. sink.batch.complete == 0
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SINK, name: sink1. sink.batch.empty == 12
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SINK, name: sink1. sink.batch.underflow == 1
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SINK, name: sink1. sink.connection.closed.count == 1
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SINK, name: sink1. sink.connection.creation.count == 1
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SINK, name: sink1. sink.connection.failed.count == 0
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SINK, name: sink1. sink.event.drain.attempt == 1
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SINK, name: sink1. sink.event.drain.sucess == 1
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Component type: SOURCE, name: source1 stopped
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. source.start.time == 1557911004901
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. source.stop.time == 1557911046329
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.append-batch.accepted == 1
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.append-batch.received == 1
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.append.accepted == 0
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.append.received == 0
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.events.accepted == 1
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.events.received == 1
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: SOURCE, name: source1. src.open-connection.count == 0
# 19/05/15 09:04:06 INFO source.SpoolDirectorySource: SpoolDir source source1 stopped. Metrics: SOURCE:source1{src.events.accepted=1, src.events.received=1, src.append.accepted=0, src.append-batch.accepted=1, src.open-connection.count=0, src.append-batch.received=1, src.append.received=0}
# 19/05/15 09:04:06 INFO file.FileChannel: Stopping FileChannel channel1 { dataDirs: [/root/.flume/file-channel/data] }...
# 19/05/15 09:04:06 INFO file.EventQueueBackingStoreFile: Start checkpoint for /root/.flume/file-channel/checkpoint/checkpoint, elements to sync = 0
# 19/05/15 09:04:06 INFO file.EventQueueBackingStoreFile: Updating checkpoint metadata: logWriteOrderID: 1557911004126, queueSize: 0, queueHead: 0
# 19/05/15 09:04:06 INFO file.Log: Updated checkpoint for file: /root/.flume/file-channel/data/log-9 position: 172 logWriteOrderID: 1557911004126
# Attempting to shutdown background worker.
# 19/05/15 09:04:06 INFO file.Log: Attempting to shutdown background worker.
# 19/05/15 09:04:06 INFO file.LogFile: Closing /root/.flume/file-channel/data/log-9
# 19/05/15 09:04:06 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-8
# 19/05/15 09:04:06 INFO file.LogFile: Closing RandomReader /root/.flume/file-channel/data/log-9
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Component type: CHANNEL, name: channel1 stopped
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.start.time == 1557911004363
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.stop.time == 1557911046372
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.capacity == 1000000
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.current.size == 0
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.event.put.attempt == 1
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.event.put.success == 1
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.event.take.attempt == 14
# 19/05/15 09:04:06 INFO instrumentation.MonitoredCounterGroup: Shutdown Metric for type: CHANNEL, name: channel1. channel.event.take.success == 1
# 19/05/15 09:04:06 INFO node.PollingPropertiesFileConfigurationProvider: Configuration provider stopping

# %% [markdown]
# Mientras la celda de arriba se está ejecutando, debemos abrir un terminal y ejecutamos los comandos siguientes:
#
# docker exec -ti CONTAINERID /bin/bash
#
# echo "DDDDDDD prueba" > /tmp/spooldir/.fileD.txt
#
# mv /tmp/spooldir/.fileD.txt /tmp/spooldir/fileD.txt
#
# Estas ordenes sirven para crear un /ficherollamado .fileD.txt en la ruta indicada y despues lo renombramos a fileD.txt
#
# Repite estas órdenes varias veces cambiando los nombres de los ficheros.
#
# Tras ejecutar esas ordenes, tenemos que parar el agente para poder seguir ejecutando la siguiente celda de este notebook.

# %%
! hadoop fs -ls  /user/cloudera/ejflumehdfs
# Out:
# Found 2 items
# -rw-r--r--   1 root cloudera         17 2019-05-15 09:02 /user/cloudera/ejflumehdfs/FlumeData.1557910940697
# -rw-r--r--   1 root cloudera         16 2019-05-15 09:04 /user/cloudera/ejflumehdfs/FlumeData.1557911024881

# %%
! hadoop fs -cat /user/cloudera/ejflumehdfs/FlumeData.1557911024881
# Out:
# FFFFFFFF prueba
