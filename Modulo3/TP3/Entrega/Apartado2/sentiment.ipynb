# %% [markdown]
# Francisco Javier Piqueras Martínez

# %% [markdown]
# # TP3 - Apartado 2 - Infraestructuras Computacionales para el Procesamiento de Datos Masivos
# ## Ejercicio 3
#
# Una de las aplicaciones más interesantes que se pueden realizar sobre la información que se recopila de Twitter es el denominado análisis de sentimiento o sentiment analysis. Se trata fundamentalmente de clasificar de forma automática la polaridad de un tweet en concreto, en función de su contenido, categorizándolo como positivo, negativo o neutro, e incluso asignándole un valor numérico a dicha clasificación. Esta funcionalidad se utiliza, por ejemplo, en sistemas de análisis de reputación online (Online Reputation Management, ORM) para determinar qué se está diciendo de una determinada marca en Twitter, en tiempo real.
#
# En este ejercicio vamos a simular, de forma simplificada, un sistema de tiempo real que ofrezca una puntuación de polaridad (positiva, negativa o neutra) a los tweets que vayan llegando. Para ello, el modelo de clasificación se basará en listas de palabras, denominadas lexicones. En concreto, dispondremos de un lexicón de palabras positivas y su puntuación, “positive_lex.txt”, y de un lexicón de palabras negativas y su puntuación, “negative_lex.txt”. Ambos contienen, en cada línea, una palabra (positiva o negativa, respectivamente), seguida de su puntuación. Nótese que la polaridad negativa ya está expresada con un signo menos.
#
# Se pide desarrollar un notebook de Jupyter, denominado “sentiment.ipynb”, en el que se utilice como fuente de datos Kafka, y en concreto el topic kafkaTwitter. Para cada nuevo tweet que llegue al sistema, se analizará su polaridad dividiendo el tweet por palabras y realizando la suma de la polaridad de todas las palabras que aparezcan en los ficheros “positive_lex.txt” y “negative_lex.txt”. Las palabras del lexicon negativo tienen un signo menos delante, por lo que restarán a la puntuación final del tweet. Si ninguna de las palabras del tweet está almacenada en los ficheros proporcionados (o si las puntuaciones de las palabras positivas y negativas se anulan), la polaridad del tweet será 0.
#
# La salida del sistema ha de imprimirse cada segundo, y consistirá en una línea por cada tweet recibido, que contenga el texto del propio tweet, a continuación la puntuación de su polaridad, y la palabra “NEUTRO” si la puntuación es igual 0, “POSITIVO” si es mayor que 0, y “NEGATIVO” si es menor que 0.

# %%
# Leemos todas las palabras con connotación positiva del arcihvo positive_lex.txt
positive_words = []
with open('../resources/positive_lex.txt', 'r') as p:
    pos = [line.strip() for line in p]
for line in pos:
    positive_words.append(line.split(' '))

# %%
# Leemos todas las palabras con connotación negativa del archivo negative_lex.txt
negative_words = []
with open('../resources/negative_lex.txt', 'r') as n:
    neg = [line.strip() for line in n]
for line in neg:
    negative_words.append(line.split(' '))

# %% [markdown]
# Realizamos todos los imports necesarios:

# %%
import findspark
findspark.init('/Users/javierpiquerasmartinez/dev/spark-2.4.4-bin-hadoop2.7')

# %%
import os
os.environ['JAVA_HOME']='/Library/Java/JavaVirtualMachines/jdk1.8.0_231.jdk/Contents/Home/jre'
os.environ['PYSPARK_SUBMIT_ARGS']='--master local[*] --packages org.apache.spark:spark-streaming-kafka-0-8_2.11:2.4.4 pyspark-shell'

# %%
import pyspark
import pyspark.streaming
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils

# %% [markdown]
# Inicializamos SparkContext y el StreamingContext, con una duración de batch de 1 segundo.

# %%
sc = SparkContext(master="local[*]", appName="Hashtags")
ssc = StreamingContext(sc, batchDuration=1)
ssc.checkpoint("checkpoint")

# %% [markdown]
# Para la recepción de datos, creamos un DirectStream que atienda a el evento 'kafkaTwitter' en el servidor localhost:9092.

# %%
dstream = KafkaUtils.createDirectStream(
    ssc, 
    topics = ['kafkaTwitter'],
    kafkaParams = {
        'bootstrap.servers' : 'localhost:9092'
    })

# %% [markdown]
# Definimos las funciones que nos van a ayudar a calcular la puntuación y el resultado.

# %%
def getScore(tweet):
    words = tweet.split(' ');
    sc = 0
    for pos_word in positive_words:
        for word in words:
            if(pos_word[0] == word):
                sc+=float(pos_word[1])
    for neg_word in negative_words:
        for word in words:
            if(neg_word[0] == word):
                sc+=float(neg_word[1])
    return sc

def getSentiment(score):
    if score>0:
        return 'POSITIVO'
    elif score<0:
        return 'NEGATIVO'
    else:
        return 'NEUTRO'

# %% [markdown]
# Formamos la respuesta para su devolución:

# %%
result = dstream.map(
    lambda tweet: [tweet[1], getScore(tweet[1]), getSentiment(getScore(tweet[1]))]
)

# %%
result.pprint()

# %%
ssc.start()
# Out:
# -------------------------------------------
# Time: 2020-01-12 19:33:09
# -------------------------------------------
# ['"Los problemas de la gente no se solucionan con escenografías, maquillajes o cambios de logos" @pbustinduy #L6Nbarómetro', 0.375, 'POSITIVO']
# ['@VideojuegosGAME gracias :D', 0, 'NEUTRO']
# ['Dedicado a los que inician parciales...porque yo tambn pasé por ahí @JUANCAORTIZ14 @los40colombia #Noches40 :D http://t.co/c9m35mCBtR', 0, 'NEUTRO']
# ["Los globos de Google 'con internet para todos' ya están casi listos (video) - http://t.co/jQp8xEub0V http://t.co/GFdIEkwF0B", 0, 'NEUTRO']
# ['Nena, hiciste que mi varita se levantara sin usar Wingardium Leviosa. ..#FrasesparaligardeHoward', 0, 'NEUTRO']
# ['Comienza la intervención de @marianorajoy. Ya en directo en http://t.co/08eZ0fzjAi #TrabajarHacerCrecer', 0.26, 'POSITIVO']
# ['@TownGamePlay feliz domingo, mañana entró de vacaciones :D', 1.0939999999999999, 'POSITIVO']
# ['Buenas tardes gentecilla!! :D.Tremenda viciadita me he pegado hoy al BO3,eso sí... he cogido otros modos y no veas la paliza jajaja +', 0.375, 'POSITIVO']
# ['@Abel_Kills @Tanzi18 Y un arroz con abichuelas :D', -0.375, 'NEGATIVO']
# ['John Nash como un héroe trágico griego, retrato de David Fernández (ICMAT) en @elmundoes http://t.co/NkcWBYU5WW', -0.812, 'NEGATIVO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:10
# -------------------------------------------
# ['Estos carteles de SpaceX harán que quieras vivir en Marte - http://t.co/D7xd7oGvmD http://t.co/eBZYx3VR49', 0, 'NEUTRO']
# ['Mi amor no se puede quemar porque es fuego, ni ganar ni perder porque no es un juego... Jm.', 0.653, 'POSITIVO']
# ['Me parece indignante y vergonzoso que casi en 2015 y en pleno centro de Madrid echen del Burger King a unos amigos gays por besarse. GENTUZA', -0.062, 'NEGATIVO']
# ['SALTO DE FÉ! - Los Juegos Del Hambre: http://t.co/pRMS2Eo6WX vía @YouTube', 0, 'NEUTRO']
0, 'NEUTRO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:15
# -------------------------------------------
# ['Texto en @larazon_es sobre Elvira Fernández (Mujer de Rajoy) propio del siglo XIX o la sección femenina. http://t.co/OxcvvuBDn0', 0.25, 'POSITIVO']
# ['@XOLE_RUBIK Hay mucho tonto suelto Xole, tú sigue con lo tuyo que lo haces muy bien, ¡¡y a disfrutar del x13!! :D', 0.272, 'POSITIVO']
# ['@iechavarri últimamente sí.. }:S', 0, 'NEUTRO']
# ['¿Nos pasamos con los deberes en España? Somos el cuarto país con más horas a la semana: 1,6 más que la media OCDE http://t.co/V9qBwgooj8', -0.25, 'NEGATIVO']
# ['Agradecer a @worldclasshats por entregar DON Camparino antes do final de semana. :P http://t.co/4KzjWc1QDt', 0, 'NEUTRO']
# ['Buena imagen para reflexionar... http://t.co/KseHem0RSH', 0, 'NEUTRO']
# ['Google Maps añade navegación offline punto por punto http://t.co/V8Ch1Zo0x1 http://t.co/0kWA2167a2', 0, 'NEUTRO']
# ['J.Luis Rodríguez Zapatero: Pedro deseaba que la libertad no tuviera barreras, que los discriminados de forma injusta recuperaran su libertad', 0.375, 'POSITIVO']
# ['Bienvenidos al @QPachow todos los que estrenan horario tempranero! Hoy @OyeGustavoTello @oyealbert897 e invitada de lujo @oyecarlabarreto :D', 0, 'NEUTRO']
# ['Hoy estreno lectura (gracias a @Biblioteca_UAM) http://t.co/u5jecQPAYz', 0, 'NEUTRO']
# ...
# -------------------------------------------
# Time: 2020-01-12 19:33:16
# -------------------------------------------
# ['@GarciaG_Andres Si no hay lista de espera será pq se han cubierto las plazas. De todas formas, ponte en contacto con @UAM_Medicina Saludos', 0.625, 'POSITIVO']
# ['@Ana_Libroblogs ¡Sí, pero hace muchísimo tiempo! Recuerdo que tenía un mundo muy interesante y Yoko como protagonista era genial :D', 0.849, 'POSITIVO']
# ['Así es Endgame: la novela que se convierte en realidad gracias a Ingress http://t.co/0oIX8EZruz http://t.co/A4k6uIv8v6', 0, 'NEUTRO']
# ['@MartellitasOffi Hola :D ¿De casualidad sabes que precio tienen? :33', 0, 'NEUTRO']
# ['No nací para estar de novia. Me estresa demasiado los gatos y los pelotudos que les siguen el juego bai', 0.375, 'POSITIVO']
# ['@nazary_gr  Emi, Ceballos, Eraso y nauzet/pina, juego con 4 medios. Venderías a Nauzet/pina por Sarabia? Tendría dos del Getafe..', 0, 'NEUTRO']
# ['Titanic versión pingüino.  http://t.co/m70rqXQJcw', 0, 'NEUTRO']
# ['Seguimos en directo!! :D ..https://t.co/YMqoRtfJpz', 0, 'NEUTRO']
# ["George RR Martin pasandose a GNU/Linux sólo por darse el gustazo de usar el comando 'killall'.", 0, 'NEUTRO']
# ['A bosnios y europeos: construyamos una sociedad democrática, en libertad, con justicia social e igualdad #Srebrenica http://t.co/6ZhPOQ3yL9', 0.643, 'POSITIVO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33
 0, 'NEUTRO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:21
# -------------------------------------------
# ['Mola pero se nota que le han robado la coreografía a Miley Cyrus http://t.co/Nj8uvXxWb1', 0, 'NEUTRO']
# ['#ForoCambio11J "Las diferencias económicas marcan diferencias en el sistema educativo, se segrega a los alumnos" @SoyPublica', 0, 'NEUTRO']
# ['Duermen tranquilos después de cargarse buena parte de las ayudas a los dependientes, los más débiles. https://t.co/BLN8sED3Xp', -0.625, 'NEGATIVO']
# ['Primarias abiertas y ciudadanas donde cualquier persona puede participar: http://t.co/OP525tjwDE #EnPodemosTúDecides http://t.co/F8yZuLb8ws', 0, 'NEUTRO']
# ['¿qué pasa? Juego al principio de la season donde subo rápido y ale ya soy un puto oro platino.', -0.05699999999999994, 'NEGATIVO']
# ['¿Sabes lo que significa la palabra HACKER? No es lo que piensas, ahora @Chemaalonso lo aclara http://t.co/83lp0Z5bov #yuVenenoDeSerpiente', 0, 'NEUTRO']
# ['¡Me encanta jugar #Apensar! Disponible en App Store http://t.co/FwoFOoZVdB y en Google Play http://t.co/bnnKQvsDqQ http://t.co/pzq2oeXjyb', 0, 'NEUTRO']
# ['Si duermo una hora de siesta, al despertar me odio a mi mismo. Si duermo dos, odio al mundo. El día que duerma 8 horas os vais a cagar', -1.25, 'NEGATIVO']
# ['que pequeño es este mundo :D', 0, 'NEUTRO']
# ['No tendre ni agua en la nevera pero... Jejejee http://t.co/IRBrmz4Idz', -0.25, 'NEGATIVO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:22
# -------------------------------------------
# ['@AsahiinaCynthia https://t.co/Y9TLhFa0GW este es uno de mis videos,seguro que te gusta,suscríbete por favor,muchas gracias :D', 0, 'NEUTRO']
# [':D luego mas fotos', 0, 'NEUTRO']
# ['¡Hacemos RECOGIDA DE MATERIAL ESCOLAR! El local habilitado está en la planta calle, enfrente de la entrada sur. :) http://t.co/yA1qYg19Sd', 0.25, 'POSITIVO']
# ['Hay Saiyajins poderosos y valientes, también humanos con más poder de lo normal... luego esta Bulma :D', 0, 'NEUTRO']
# ['@danielpanam @manoloalvarezc así que Chaluja es el que dice quien juego o no, muy mal eso? Los caprichos de dirigentes afectan deporte', -0.375, 'NEGATIVO']
# ['.@SandraBarnedaa está más que lista. En unos minutos comenzamos con @equipoGabilondo y @ccifuentes http://t.co/NeW46roGVH', 0, 'NEUTRO']
# ['@CarlosVermut + @vengamonjas han cumplido. Don Pepe Popi es muy gordo: http://t.co/0bfnFB4M', 0, 'NEUTRO']
# ['Me piro a darle mas caña a youtube :D', 0, 'NEUTRO']
# ['Hoy he presentado mi candidatura a la presidencia del @PES_PSE. Cuento con tu apoyo https://t.co/xbW3ybwP33 #Enrique4PES @activistasPES', 0, 'NEUTRO']
# ['Nena, eres el CSS de mi HTML, tienes &lt;STYLE&gt;, nunca sales de mi  &lt;HEAD&gt; y tú &lt;BODY&gt; es perfecto..  .#FrasesparaligardeHoward', 0, 'NEUTRO']
# ...
# -------------------------------------------
# Time: 2020-01-12 19:33:23
# -------------------------------------------
# ['Agradezco su labor al @ppvasco, sinónimo de libertad, lucha contra el terrorismo y apoyo constante a las víctimas #TrabajarHacerCrecer', 0.21899999999999997, 'POSITIVO']
# ['Ya disponible #APP de cultura científica #UAM @UAM_Gazette ,\u200ben Apple Store y Google Play http://t.co/drCapI5syB http://t.co/lODzHFk5zQ', 0.292, 'POSITIVO']
# ['Que tal como va todo!? Le acabo de contar al taxista como me gano la vida como hacker informatico😂 le he dicho que por favor no me delate!', 1.25, 'POSITIVO']
# ['Seguimos jugando a Dying Light. ¡En cooperativo! http://t.co/DVgKmNTu5u', 0, 'NEUTRO']
# ['Lo mejor y lo peor del... Samsung Galaxy S5 - http://t.co/VSmruXJGBQ http://t.co/1AdtmRAdOP', 0.375, 'POSITIVO']
# ['@SaraRamirez Tuitea más seguido en español, me hace feliz que lo hagas :D', 0.719, 'POSITIVO']
# ['@WillyrexYT  @YouTube te queremos =) sos lo mejor que hay en el planeta #APOCALIPSISMINECRAFT4 http://t.co/DmAfQsm1Zz', 0.375, 'POSITIVO']
# ['Transforman las cabinas rojas de Londres en estaciones de carga solares - http://t.co/94ksVfe1yT http://t.co/rN8WzQ1F4c', 0, 'NEUTRO']
# ['@MultiGamingES @UnicLuart con la mano tambien se puede :P', 0, 'NEUTRO']
# ['Acá. .terminó mi lunes super activo :D #echobosta #adormir… https://t.co/2UVKuG1sTR', 0.625, 'POSITIVO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:24
# -------------------------------------------
# ['http://t.co/pv96B5roNs Pásate, si no quieres no hay problema, devuelvo :p — algún día... http://t.co/ddXgV0143h', 0.75, 'POSITIVO']
# ['Xanadú está llenos de punkis.', 0, 'NEUTRO']
# ['Más votada 24h: La Guardia Civil caza al alcalde de Alcañiz a 211 km/h en una carretera de 100 https://t.co/90jSEVBaww', 0, 'NEUTRO']
# ['No vamos a dar ningún cheque en blanco.Seremos exigentes en nuestros pactos @sanchezcastejon #PedroSánchezconPiqueras http://t.co/W0cKln3FKq', -0.75, 'NEGATIVO']
# ['Y comenzando mi Domingo de la mejor manera :D #NosJuimos', 0.375, 'POSITIVO']
# ['Auroras boreales: ¿Qué son y cómo se forman? http://t.co/BU97WJvxLi http://t.co/1FumhzIdZE', 0, 'NEUTRO']
# ['No se puede ver el código fuente de la constitución, pero para mí que es un problema de llaves mal emparejadas en los artículos 167 y 168', -1.187, 'NEGATIVO']
# ['@JesterTwoOne ya estoy escondida bajo las cobijas :(', 0, 'NEUTRO']
# ['Jesús Lizcano: "Un urgente antídoto contra la corrupción", vía @larazon_es http://t.co/AG4wI9hOCk', 0, 'NEUTRO']
# ['@Richard46763975 @Riscacumguy yo te levanto el animo :D', 0, 'NEUTRO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:25
# -------------------------------------------
# ['¡Cree en la magia, muggle!', 0, 'NEUTRO']
# ['#EXODIRECTO. Nanana saludos i Love exo :D', 0, 'NEUTRO']
# ['Cosas de privilegiados: https://t.co/uDyABygBp7 https://t.co/7Hls3ce6Op', 0, 'NEUTRO']
# ['Compañeros de Podemos apoyando a @RamonEspinar en su toma de posesión. Gente común entrando en las instituciones http://t.co/ROB55W7kr7', 0, 'NEUTRO']
# ['Te toca — Ya te hice las 5 preguntas :D http://t.co/Gn3BmV7hR5', 0, 'NEUTRO']
# ['Más leída 24h: Internet va lento hoy, sí, pero no es culpa de tu ISP https://t.co/QPu11jybB5', -0.375, 'NEGATIVO']
# ['@v_delacroix Que descanses :D', 0, 'NEUTRO']
# ['Sólo por no abrir Photoshop ya merece la pena http://t.co/3PlGZLlBTN', -0.08300000000000002, 'NEGATIVO']
# ['Un IVA superreducido en alimentos aptos para celiacos que reduzca sobrecoste en alimentación: http://t.co/QITnWSisbq.#DíaNacionaldelCeliaco', 0, 'NEUTRO']
# ['#PSOE24M kedan solo 2 horas pra saber con seguridad k @JuanEspadasSVQ será Alcalde d #Sevilla http://t.co/UXG0ABkvkP', -0.25, 'NEGATIVO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:26
# -------------------------------------------
# ['Los factores ambientales que más influyen en el envejecimiento http://t.co/qgfGiFfdA2 http://t.co/JWISbekRj7', 0, 'NEUTRO']
# ['Pues con #chappaypintura. ¿Cómo maquillar la realidad de los últimos 4 años en 4 sencillos pasos? #ChaPPayPPintura https://t.co/xkNSprnFr2', 0, 'NEUTRO']
# ['LA PICADURA LETAL!! ARK: Survival Evolved #13: http://t.co/S4ClEd0iVL vía @YouTube', 0, 'NEUTRO']
# ['encima me bardea por ellos y estan saliendo o_O jajaja, ojala se casen y quedes de cara y veas que no mentía :P', 0.375, 'POSITIVO']
# ['Buenos días buenos días buenos días buenos días :D !!', 0, 'NEUTRO']
# ['Este PC personalizado de Minecraft es perfecto para los fans del juego http://t.co/v2ruvvlnwC', 0.875, 'POSITIVO']
# ['El periódico @sendanorte también opina sobre la apertura en @RCristalera del punto de info sobre el Parque Nacional http://t.co/ElZqyQYRSh', 0, 'NEUTRO']
# ['La BlackBerry Passport de AT&amp;T pierde sus características esquinas - http://t.co/KBLBIRGtPC http://t.co/7Q2Y6UD2jn', 0, 'NEUTRO']
# ['@_aniittaa__ si hagués posat "açó" en comptes d\' "aixó" hagués reconegut la diferència :P', 0, 'NEUTRO']
# ['#BuenDomingo :D esperando los canelones!! :D', 0, 'NEUTRO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:27
# -------------------------------------------
# ['@Rubiu5  qe felicidad :D', 0.708, 'POSITIVO']
# ['¿Por qué sentimos picor? http://t.co/73WgSNIYpB http://t.co/s5Anb20urA', 0, 'NEUTRO']
# ['Odio madrugar en verano :-(', 0, 'NEUTRO']
# ['@aka_mepi La camiseta que me regaló @JaviPolo91  :__) http://t.co/zwBcz9MCYn', 0, 'NEUTRO']
# ['Disfrutaré este resfriado como si fuera el último', -0.25, 'NEGATIVO']
# ["Sony anunciará el próximo día 5 algo llamado 'EMAGON' - http://t.co/mwMVtFzgyK http://t.co/yPXdrdZQRs", 0, 'NEUTRO']
# ['No es que haya desaparecido #Cantoblanco ....es que hay niebla!!! Buen Lunes!!! http://t.co/h4yhyOowHV', 0, 'NEUTRO']
# ['"El viraje de los socialistas europeos es necesario y les tendemos la mano para ello" @Pablo_Iglesias_ #RdPPodemos', 0, 'NEUTRO']
# ['Mi PC Suite, la herramienta de Xiaomi para controlar tu movil http://t.co/CD0iMNLmIh http://t.co/ZAyLsouAkD', 0, 'NEUTRO']
# ['@ppr1994 ganó la misma empresa que ya las tenía hasta ahora, pero para que el concurso fuera justo, no podía usar las mismas que ya tenía', 0.125, 'POSITIVO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:28
# -------------------------------------------
# ['Ya la pelea por los Tag Team Titles? SIIIIII :D #SummerSlam', -0.406, 'NEGATIVO']
# ['¿Qué es lo más crujiente del mundo?', 0.375, 'POSITIVO']
# ['¿Conoces los mitos del running? http://t.co/V1FmB0tfWk http://t.co/Pgt5VoEf8S', 0, 'NEUTRO']
# ['El oso Rulo :D', 0, 'NEUTRO']
# ['Mi cuarto en estos momentos :D http://t.co/ax9hF8e5dC', 0, 'NEUTRO']
# ['Relacionan benzodiazepinas y analgésicos con el riesgo de asesinato http://t.co/3v5LbRPUqo http://t.co/j8IIdYVXLu', -0.625, 'NEGATIVO']
# ['@NoeliadelLlano es un juego para pc así que con Nintendo no pinta mucho y además no lo van a sacar xD', 0.375, 'POSITIVO']
# ['[Espanol con Ñ] Esperando los sobres y retas con viewers! :D: http://t.co/HwtKK4l9fd', 0, 'NEUTRO']
# ['Ángel Gabilondo: Garantizo que gestionaré lo público con consenso, diálogo, participación e interés general.#DebateCifuentesGabilondoEnLaSER', 0.759, 'POSITIVO']
# ['La psicología del ganador... http://t.co/T8mAlqkLTE http://t.co/3IqQEoRjxo', 0, 'NEUTRO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:29
# -------------------------------------------
# ['Ya tengo listo el video de la semana. Lo iba a subir hasta mañana pero creo que mejor hoy :D.', 0.762, 'POSITIVO']
# ['@carlosforozco97 Gracias :D Fue genial !!!!', 0.661, 'POSITIVO']
# ['La extraño mucho :´( http://t.co/xe2jaUMM7q', 0, 'NEUTRO']
# ['Esta noche y con los resultados de Tucumán, Macri se consagrará definitivamente como el "Gran Consolador de Candidatos Derrotados" :P', 0, 'NEUTRO']
# ['¿Que ocurre en nuestro cerebro cuando no pensamos en nada? http://t.co/8LcuEDEBjR http://t.co/ZY34zjwcvV', 0.375, 'POSITIVO']
# ['.@TAZ_JCGC Si cada vez que le llaman tonto cree usted que se la están chupando, debe de ir muy satisfecho por la vida. :D', 0.586, 'POSITIVO']
# ['El armadillo es el único animal que si fuera un pokémon, se autocapturaría. http://t.co/Ktbf0z8cRK', -0.04200000000000004, 'NEGATIVO']
# ['Día de celebración y fiesta. Damos un paso más para decir adiós a la intolerancia #OrgulloDelCambio #Orgullo2015 http://t.co/DH1qeVpAAd', -0.22899999999999998, 'NEGATIVO']
# ['Más leída 24h: La cerdada electoral https://t.co/xbLhMhh8cA', 0, 'NEUTRO']
# ['@RunnierHellin -- porque en el de pc juego con teclado y apenas lo pongo', -0.312, 'NEGATIVO']
# ...
# -------------------------------------------
# Time: 2020-01-12 19:33:30
# -------------------------------------------
# ['@eduardogui84 Hola :D aquí te comparto algo de música nueva http://t.co/GAv4Nwt4wB  Espero te agrade http://t.co/5nf0GrVP3C  Saludos^^', 0, 'NEUTRO']
# ['Ay qué día tan estupendo :D', 0, 'NEUTRO']
# ['@Arnau_xPop @Burning_Light_ Me recomendarian algun juego para pc? De pokemon ^^', 0, 'NEUTRO']
# ['@anxietyblow Takero mucho :D jajaja xD', 0, 'NEUTRO']
# ['.@PPrada2015 ”El PP en el Exterior aportará nuevas propuestas al Programa Electoral” http://t.co/CHaE6CM4Qr', 0.25, 'POSITIVO']
# ['"La conferencia ha servido para hacer terapia, para reflexionar y ver qué tenemos que cambiar, hacer y explicar" @ccifuentes #Cifuentes13tv', 0, 'NEUTRO']
# ['Matt Groening se quedo sin extras para este episodio… http://t.co/jb6X5pktuf', 0, 'NEUTRO']
# ['El robot albañil Hadrian podría colocar los ladrillos de una casa completa en un par de días https://t.co/rOWiiI8ciG http://t.co/On2Wvt96SK', -0.375, 'NEGATIVO']
# ['@PastorVladimir @IglesiaCompaz mi pastor es que donde hay cordero es porque esta la sangre en los dindeles de la puerta :D', 0, 'NEUTRO']
# ['@PachVader que me den gas? :D', 0, 'NEUTRO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:31
# -------------------------------------------
# ['Lo bueno de vivir en China es que cuando se te pierde el nene en la playa agarras otro y listo :D', 0.887, 'POSITIVO']
# ['Hoy había demasiada gente en el gimnasio. Quiero decir, que había demasiada gente en el Burger King. Pero yo voy de todas formas.', 0, 'NEUTRO']
# ['.@sanchezcastejon  y el líder de los socialistas portugueses se comprometen en Lisboa a impulsar la cooperación y la integración ibérica', 0, 'NEUTRO']
# ['Ahora mismo mataría por un arroz tres delicias de un restaurante chino de España... QUE HAMBREEE!!', -0.75, 'NEGATIVO']
# ['Madre china se niega a que rompan las ventanillas de su BMW para salvar a su hijo del... https://t.co/i7HtOPy3EO http://t.co/MOkpG2rtCy', 0, 'NEUTRO']
# ['VÍDEO El que passa quan Dirk Kuyt anuncia als seus fills que torna al @Feyenoord #futbolint http://t.co/gEnE7nv16F http://t.co/XFT3Jz04xK', 0, 'NEUTRO']
# ['@jQdarp buenísima foto, Daniel, muchas gracias por visitarnos :D', 0, 'NEUTRO']
# ['Mates , Tutuca y Partido de bocaa :D', 0, 'NEUTRO']
# ['"España no se parece en nada a la España en la que se redactó el Estatuto de los Trabajadores". @LuzPSOE #DesayunosTVE @La1_tve @24h_tve', 0.375, 'POSITIVO']
# ['Google estaría trabajando en un competidor de WhatsApp - http://t.co/99VKW5RLtr http://t.co/dlgcy3vmON', -0.625, 'NEGATIVO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:32
# -------------------------------------------
# ['@5SOSLA_NOTICIAS fue hoy a la mañana (mi alarma) puse SKH y me puse a cantar y a saltar en la cama :p #ShesKindaHotVMA', 0, 'NEUTRO']
# ['@somozaaa @somozaaa Cierto. En Wikipedia aceptan «templado», pero para «clavecín» http://t.co/yLL4KM2sf5 ¡Gracias por el matiz! –@Alvy', 0, 'NEUTRO']
# ['OnePlus quiere estar a la altura de Apple y Samsung en 5 años http://t.co/8xQZYnVUdU Ejem... http://t.co/PrvTfc8zOg', 0, 'NEUTRO']
# ['@SheldonSuck me gustaría hablar con vos pero solo tengo el 99% de batería, hablamos otro día : )', 0, 'NEUTRO']
# ['@Sra_Gatoo Hola mira mi canal en youtube espero te guste bonito dia :D.https://t.co/AbcdjNAZ6R', 0.75, 'POSITIVO']
# ['@AlvDavo Ay DIOS! este hombre me va hacer llorar de la felicidad! :D ♥ TE QUIEROOO! QUEDATE! ♥', -0.667, 'NEGATIVO']
# ['"perche" wannabe made by us jaaa asi o más piratas!!! Jaaa pero bn buenos :D jaa https://t.co/3FmIv0MZC4', 0, 'NEUTRO']
# ['He estado una hora mirando al techo o ha sido cosa mía.  #tuestemáximo', 0, 'NEUTRO']
# ['Las galletas #toddy son una vaina del demonio mesmo', -0.25, 'NEGATIVO']
# ['Esto hay que decirlo más https://t.co/nNUPMGvVcZ', 0, 'NEUTRO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:33
# -------------------------------------------
# ['@GamalLiranzo Si duran, celebran, si no duran no es culpa suya. Curioso :p', 0.0, 'NEUTRO']
# ['Gobernaremos para la mayoría.Para una recuperación justa y #EmpleoDigno.  Fortaleceremos los servicios públicos http://t.co/phgNpKelDm', 0, 'NEUTRO']
# ['Sale a la luz la factura del exastronauta Buzz Aldrin cuando viajó a la Luna https://t.co/vyBWbZDGKq http://t.co/1m5qzQnVTP', 0, 'NEUTRO']
# ['Y acabo de descubrir que estaba usando la API mal. Cambiando unas cosas ahora me va 100 veces más rápido...', 0, 'NEUTRO']
# ['HOGAR PARA MIS DINOSAURIOS!! ARK: Survival Evolved #9 https://t.co/pPFacRl0ip vía @YouTube', 0, 'NEUTRO']
# ['El juez cierra el caso Mauthausen por la limitación de la Justicia Universal Impunidad para nazis cortesía de Rajoy http://t.co/9DUDJVwa7W', 0.271, 'POSITIVO']
# ['@Heikki_360 en el PES sigue estando el juan carlos rivero? es que no lo juego desde el pes 6 con mods para PC', 0.375, 'POSITIVO']
# ['“@fayerwayer: Europa a punto de demandar formalmente a Google http://t.co/CE7PcC643L” Google operador dominante http://t.co/3jPdRWSTLT }:0', -0.3, 'NEGATIVO']
# ['Ponle como.favorito so alguna ves  jugaste este juego http://t.co/BhPbZa4HU0', 0, 'NEUTRO']
# ['@frutillitadulc1 creo que sí', -0.25, 'NEGATIVO']
# ...
#
# -------------------------------------------
# Time: 2020-01-12 19:33:34
# -------------------------------------------
# ['#Cmin Comienza la rueda de prensa de la vicepresidenta Sáenz de Santamaría. En #directo: http://t.co/PTrZkAu8NH', 0, 'NEUTRO']
# ['@ChristianDT_14 Graciass!! :D', 0, 'NEUTRO']
# ['¿Cuáles son las líneas rojas del Estado del bienestar? El miércoles 18 tenéis una cita en @derecho_uam. Más info http://t.co/5fENQGZh6y #UAM', 0, 'NEUTRO']
# ['Vídeo: así «funciona» la resonancia #ciencia http://t.co/fcgLMsdU2A http://t.co/tWyRO4gZM9', 0, 'NEUTRO']
# ['Lo más romántico por @iWolowitz http://t.co/XdIiLriWhS http://t.co/IZrPTGdgEE', 0, 'NEUTRO']
# ['Pues me despido de BO3 ... :__( ..Han sido unos días de 10 con los directos!! De verdad que estoy contentísimo con el apoyo recibido :D &lt;3', 0.3, 'POSITIVO']
# ['Buen intento… http://t.co/9C9mLUBlGS', 0, 'NEUTRO']
# ['Jugando con Android: MOOC gratuito impartido en @UAM_Madrid http://t.co/Pr1KcJdII1 @EPS_UAM http://t.co/oaRFCqOVQG', -0.281, 'NEGATIVO']
# ['Siempre se pueden aprender cosas nuevas sobre M.C. Escher .http://t.co/HfMIQFf02n.vía @FastCompany http://t.co/BrH7l3e9lB', 0.25, 'POSITIVO']
# ['No será quizá que es la hora ya... http://t.co/Y3APqSFV', 0, 'NEUTRO']
# ...
